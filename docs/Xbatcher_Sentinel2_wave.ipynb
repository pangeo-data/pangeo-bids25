# %% [markdown]
# # Surfing Waves with Sentinel-2: Cross-Spectra & Wavelets on HEALPix Patches
#
# This notebook is a hands-on demo showing how to build **wave spectra** from Sentinel-2 imagery over the ocean using **two 10 m bands** - **B02 (blue)** and **B04 (red)** - that are acquired with a small time offset. That slight offset means the sea surface evolves just enough between the two snapshots to unlock **cross-spectral** estimation: we can both **reduce spectral bias** and **recover wave phase and directions** from the **cross-spectrum**.
#
# Instead of classic FFTs on planar tiles, we resample to a **HEALPix** grid so that all patches share the **same surface per pixel**, then estimate spectra with **wavelets**, which are more robust to noise under the assumption that wave spectra are relatively smooth.
#
# ---
#
# ## Why B02 x B04 Cross-Spectrum?
#
# - Natural temporal offset: B02 and B04 are acquired a few moments apart. Waves evolve slightly - enough to introduce measurable phase differences while maintaining coherence.
# - Cross-spectral benefits:
#   - Bias reduction in spectral estimates (compared to single-band autospectra).
#   - Phase retrieval -> directions: the cross-spectrum’s complex phase gives propagation directions of waves.
# - 10 m resolution: fine enough to resolve short waves; the short offset keeps coherence high at these scales.
#
# ---
#
# ## Processing Overview
#
# 1. **Input**: Sentinel-2 Level-2A/Level-1C oceanic granules containing **B02** and **B04** at **10 m**.
# 2. **Patch building (UTM)**: Cut the UTM imagery into fixed **256x256 pixel** patches (~ 2.56 km on a side).
# 3. **UTM -> HEALPix**: Resample each patch onto a **HEALPix** grid so that each pixel covers the **same area** regardless of latitude.
#    *Why?* Fair comparisons of spectral energy require consistent pixel areas.
# 4. **Wavelet-based spectra**: On the HEALPix patch, compute **wavelet transforms** of B02 and B04 and form the **cross-spectrum**:
#    - Smoother, less noise-sensitive than FFTs in this setting.
#    - Provides **amplitude** (power) and **phase** (direction).
# 5. **Direction estimation**: Use the **phase** of the cross-spectrum to infer **wave directions** (and optionally phase speed proxies where applicable).
# 6. **Scaling up with xbatcher**: Demonstrate how **xbatcher** can tile large scenes and compute many spectra efficiently across lots of Sentinel-2 data.
#
# ---
#
# ## What You Will Learn
#
# - How to construct UTM **patches** and resample them to **HEALPix** while preserving radiometry.
# - How to compute **wavelet cross-spectra** between B02 and B04 to:
#   - Reduce estimation bias,
#   - Retrieve **directional** information from **phase**.
# - How to use **xbatcher** to scale the workflow (thousands of patches, large scenes).
#
# ---
#
# ## Notebook Structure
#
# ### 1) From UTM Tiles to HEALPix Patches
# - **Load** Sentinel-2 B02 & B04 (10 m).
# - **Window** into **256x256** UTM patches over ocean.
# - **Resample** each patch to **HEALPix** (choose `nside` to match resolution/area).
# - **Validate** area equivalence and basic QC checks (land mask, clouds if needed).
#
# ### 2) Wavelet Cross-Spectrum on HEALPix
# - **Wavelet transform** (per orientation/scale) on both bands.
# - Build **cross-spectrum** as B02 x conj(B04) across **scales** and **orientations**.
# - **Amplitude** -> spectral energy; **phase** -> **wave direction**.
# - **Visualize**:
#   - 2D spectral maps (k-space-like),
#   - Directional roses,
#   - Scale–orientation slices.
#
# ### 3) Scaling with xbatcher
# - Use **xbatcher** to generate patch windows automatically.
# - Compute **spectra lazily** (e.g., with Dask) and track progress.
# - Aggregate summary products (mean spectra, dominant direction maps, QC flags).
#
# ---
#
# ## Why Wavelets (Instead of FFTs)?
#
# - Locality in both scale and space helps suppress noise and edge effects.
# - Ocean wave spectra are smooth; wavelets exploit this by emphasizing coherent structures.
# - Better behaved for irregular sampling after **UTM -> HEALPix** resampling.
#
# ---
#
# ## Practical Notes
#
# - **Band pairing**: Ensure **B02/B04** are radiometrically harmonized (e.g., same masks, scaled units).
# - **Time offset**: The small acquisition lag is a feature, not a bug - enables phase-based direction retrieval.
# - **HEALPix choice**: Pick an `nside` that approximates **10 m** pixels in area (trade-off between fidelity and cost).
# - **Window size**: **256x256** in UTM balances spectral resolution and stationarity.
# - **Compute**: Use **Dask + xbatcher** to parallelize; persist intermediate HEALPix patches if reusing.
#
# ---
#
# ## Outputs
#
# - **Per-patch spectra**: amplitude and phase across **scales** and **orientations**.
# - **Directional diagnostics**: dominant **wave direction** and spread.
# - **Summary maps** (optional): mosaicked fields of dominant direction/energy.
#
# ---
#
# ## (Optional) Reproducibility Checklist
#
# - Sentinel-2 L1C/L2A reader (e.g., `rasterio`/`xarray`).
# - HEALPix utilities (e.g., `healpy` or a custom resampler).
# - Wavelet library or custom implementation for **scale–orientation** analysis.
# - `xbatcher` + `dask` for scalable tiling and compute.
# - Plotting: `matplotlib`, optional `cartopy` for geographic overviews.
#
# ---
#
# *This demo is an end-to-end recipe: from Sentinel-2 UTM tiles to HEALPix patches, then to robust wave **cross-spectra** via **wavelets**, finishing with a scalable pipeline using **xbatcher**.*

# %% [markdown]
# ## Install&import all needed packages
#
# - `xarray-eopf` provides a custom xarray backend called `"eopf-zarr"` to open and represent ESA EOPF Zarr data products in a more analysis-ready form.
# - `pystac-client` is a Python client (and CLI) for searching and working with STAC APIs and static catalogs, built on PySTAC and adding API search, paging, and conformance handling.
# - `foscat` is a Python package for synthesizing 2D or spherical (HEALPix) data via the **Cross Wavelet Scattering Transform**, useful in image component separation and denoising. This package also provides anisotropic HEALPix convolution used in this notebook.

# %%
# !pip install xarray-eopf
# !pip install pystac_client
# !pip install foscat==2025.9.4
# Out:
# Requirement already satisfied: xarray-eopf in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: affine>=2.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2.4.0)
# Requirement already satisfied: aiohttp in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (3.11.18)
# Requirement already satisfied: dask in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2025.5.0)
# Requirement already satisfied: dask-image in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2024.5.3)
# Requirement already satisfied: fsspec in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2025.3.2)
# Requirement already satisfied: numba in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (0.61.0)
# Requirement already satisfied: numpy in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2.1.3)
# Requirement already satisfied: pyproj in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (3.7.1)
# Requirement already satisfied: requests in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2.32.3)
# Requirement already satisfied: s3fs in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2025.3.2)
# Requirement already satisfied: xarray>=2024.10 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2025.7.1)
# Requirement already satisfied: xcube-resampling in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (0.1.0)
# Requirement already satisfied: zarr<3.0,>=2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray-eopf) (2.18.7)
# Requirement already satisfied: packaging>=24.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray>=2024.10->xarray-eopf) (24.2)
# Requirement already satisfied: pandas>=2.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from xarray>=2024.10->xarray-eopf) (2.2.3)
# Requirement already satisfied: asciitree in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from zarr<3.0,>=2->xarray-eopf) (0.3.3)
# Requirement already satisfied: fasteners in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from zarr<3.0,>=2->xarray-eopf) (0.19)
# Requirement already satisfied: numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from zarr<3.0,>=2->xarray-eopf) (0.15.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiohttp->xarray-eopf) (1.20.0)
# Requirement already satisfied: click>=8.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask->xarray-eopf) (8.6.1)
# Requirement already satisfied: scipy>=1.7.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask-image->xarray-eopf) (1.15.2)
# Requirement already satisfied: pims>=0.4.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask-image->xarray-eopf) (0.7)
# Requirement already satisfied: tifffile>=2018.10.18 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask-image->xarray-eopf) (2025.8.28)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from numba->xarray-eopf) (0.44.0)
# Requirement already satisfied: certifi in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pyproj->xarray-eopf) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests->xarray-eopf) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests->xarray-eopf) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests->xarray-eopf) (2.3.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from s3fs->xarray-eopf) (2.22.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (0.12.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (1.37.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (1.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (1.17.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from dask[array,dataframe]>=2024.4.1->dask-image->xarray-eopf) (21.0.0)
# Requirement already satisfied: zipp>=3.20 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->xarray-eopf) (3.21.0)
# Requirement already satisfied: deprecated in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0->zarr<3.0,>=2->xarray-eopf) (1.2.18)
# Requirement already satisfied: pytz>=2020.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2024.10->xarray-eopf) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2024.10->xarray-eopf) (2025.2)
# Requirement already satisfied: locket in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from partd>=1.4.0->dask->xarray-eopf) (1.0.0)
# Requirement already satisfied: imageio in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pims>=0.4.1->dask-image->xarray-eopf) (2.37.0)
# Requirement already satisfied: slicerator>=0.9.8 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pims>=0.4.1->dask-image->xarray-eopf) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->xarray-eopf) (1.17.0)
# Requirement already satisfied: pillow>=8.3.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from imageio->pims>=0.4.1->dask-image->xarray-eopf) (11.1.0)
# Requirement already satisfied: pystac_client in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: requests>=2.28.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pystac_client) (2.32.3)
# Requirement already satisfied: pystac>=1.10.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac_client) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pystac_client) (2.9.0.post0)
# Requirement already satisfied: jsonschema~=4.18 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac_client) (4.23.0)
# Requirement already satisfied: six>=1.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pystac_client) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (2025.1.31)
# Requirement already satisfied: attrs>=22.2.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.23.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (4.13.0)
# Requirement already satisfied: foscat==2025.9.4 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (2025.9.4)
# Requirement already satisfied: imageio in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (2.37.0)
# Requirement already satisfied: imagecodecs in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (2024.12.30)
# Requirement already satisfied: matplotlib in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (3.10.1)
# Requirement already satisfied: numpy in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (2.1.3)
# Requirement already satisfied: healpy in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (1.18.0)
# Requirement already satisfied: spherical in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from foscat==2025.9.4) (1.0.15)
# Requirement already satisfied: astropy in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from healpy->foscat==2025.9.4) (7.0.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from imageio->foscat==2025.9.4) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from matplotlib->foscat==2025.9.4) (2.9.0.post0)
# Requirement already satisfied: numba>=0.55 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from spherical->foscat==2025.9.4) (0.61.0)
# Requirement already satisfied: quaternionic>=1.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from spherical->foscat==2025.9.4) (1.0.15)
# Requirement already satisfied: scipy>=1.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from spherical->foscat==2025.9.4) (1.15.2)
# Requirement already satisfied: spinsfast>=104.2020.8 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from spherical->foscat==2025.9.4) (2022.4.10)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from numba>=0.55->spherical->foscat==2025.9.4) (0.44.0)
# Requirement already satisfied: six>=1.5 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->foscat==2025.9.4) (1.17.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from astropy->healpy->foscat==2025.9.4) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from astropy->healpy->foscat==2025.9.4) (0.2025.3.24.0.35.32)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/jmdeloui/miniconda3/envs/py311/lib/python3.11/site-packages (from astropy->healpy->foscat==2025.9.4) (6.0.2)

# %%
import xarray as xr
import pystac_client
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1) From UTM Tiles to HEALPix Patches

# %% [markdown]
# Creates and displays a local **Dask distributed client**, which launches a scheduler and worker processes on your machine to run computations in parallel and provides access to the interactive Dask dashboard.

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:46517' processes=5 threads=20, memory=15.47 GiB>

# %% [markdown]
# This cell connects to the **EOPF STAC catalog** to access cloud-optimized Sentinel-2 data, defines the **Bay of Biscay** as the study area with a specific date, and performs a STAC search for **Sentinel-2 L1C scenes** filtered by low cloud cover (<20%) and high sun elevation (>25°) to ensure clear and well-illuminated ocean imagery suitable for wave analysis.

# %%
# Access cloud-optimized Sentinel-2 data via the EOPF STAC catalog
catalog = pystac_client.Client.open("https://stac.core.eopf.eodc.eu")

# Define oceanographic study area and time window
LON, LAT = -4.5, 48  # Bay of Biscay - known for consistent wave patterns
date = "2025-06-17/2025-06-17"

# Search criteria optimized for wave analysis
collections = ["sentinel-2-l1c"]
items = list(
    catalog.search(
        datetime=date,
        collections=collections,
        intersects=dict(type="Point", coordinates=[LON, LAT]),
        query={
            "eo:cloud_cover": {
                "lt": 20
            },  # Cloud cover < 20% ensures clear ocean surface
            "view:sun_elevation": {
                "gt": 25
            },  # Filter for high sun elevation > 25° (→ sun zenith angle < 65°),
            # which places the sun near the zenith.
        },
    ).items()
)

for item in items:
    print(f"✅ {item.id}")
else:
    print("No items found for the given criteria.")
# Out:
# ✅ S2B_MSIL1C_20250617T112109_N0511_R037_T30UUU_20250617T131418
# No items found for the given criteria.

# %% [markdown]
# This cell selects the first search result (`items[0]`), then lazily opens the associated Sentinel-2 product from object storage as an **xarray DataTree** using the `eopf-zarr` backend, and finally accesses the **B02 (blue) band at 10 m resolution** within the dataset.

# %%
item = items[0]
# Open the dataset lazily from object storage
dt = xr.open_datatree(
    item.assets["product"].href,
    **item.assets["product"].extra_fields["xarray:open_datatree_kwargs"],
)

dt["measurements"]["reflectance"]["r10m"]["b02"]
# Out:
# <xarray.DataArray 'b02' (y: 10980, x: 10980)> Size: 964MB
# dask.array<open_dataset-b02, shape=(10980, 10980), dtype=float64, chunksize=(5490, 5490), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) int64 88kB 300005 300015 300025 300035 ... 409775 409785 409795
#   * y        (y) int64 88kB 5399995 5399985 5399975 ... 5290225 5290215 5290205
# Attributes: (12)

# %% [markdown]
# ### Compute Lat/Lon from UTM Grid
#
# This cell reads the dataset’s horizontal CRS code, builds a **pyproj** `CRS` object, and creates a transformer to convert coordinates from the product CRS (typically **UTM**) to **WGS84 (EPSG:4326)**.
# The UTM (Universal Transverse Mercator) system divides the Earth into 60 longitudinal zones and represents positions as **meter-based Easting/Northing** in each zone using a Transverse Mercator projection. UTM is very practical for local geometry because distances and areas are nearly preserved, but it introduces distortions at the edges of each tile — for example, the definition of the North–South direction becomes less accurate, especially at higher latitudes.
#
# This is why we convert the UTM grid into a **HEALPix grid**, which provides a consistent, equal-area pixelization of the whole globe. In HEALPix, pixel areas are conserved everywhere on Earth, and directions such as North–South can be defined without the distortions inherent in UTM.
#
# Before making this conversion, the UTM coordinates must first be transformed into a **global latitude/longitude** reference frame so the data can be correctly mapped to HEALPix indexing.

# %%
import pyproj

crs_code = dt.attrs["other_metadata"]["horizontal_CRS_code"]

# Option 1: let pyproj parse the whole string
src_crs = pyproj.CRS.from_string(crs_code)

# Option 2: strip the prefix and give only the integer
# src_crs = pyproj.CRS.from_epsg(int(crs_code.split(":")[-1]))

transformer = pyproj.Transformer.from_crs(
    src_crs,
    pyproj.CRS.from_epsg(4326),
    always_xy=True
)

# %% [markdown]
# For the demo, we reduce the tile size so the workflow runs faster.
# Thanks to **xbatcher**, the computation is automatically **split into smaller patches**, which makes the processing efficient and well-orchestrated across the dataset.
# Because each operation is performed patch by patch, the memory footprint stays low and the notebook can scale to the **entire dataset directly from a laptop**—it’s only a matter of waiting for the results.

# %%
size=slice(2*1830,3*1830)
ds=dt["measurements"]["reflectance"]["r10m"].isel(x=size,y=size).persist()
ds
# Out:
# <xarray.DataTree 'r10m'>
# Group: /
#     Dimensions:  (y: 1830, x: 1830)
#     Coordinates:
#       * x        (x) int64 15kB 336605 336615 336625 336635 ... 354875 354885 354895
#       * y        (y) int64 15kB 5363395 5363385 5363375 ... 5345125 5345115 5345105
#     Data variables:
#         b02      (y, x) float64 27MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#         b03      (y, x) float64 27MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#         b04      (y, x) float64 27MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#         b08      (y, x) float64 27MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>

# %% [markdown]
# Here we plot the two datasets to illustrate the **global field of view**, but this visualization is intended **only for the demo**.
# When working with a large dataset, this step should be skipped: the data will instead be loaded in **small batches by xbatcher**, ensuring that computations are done piece by piece and that memory usage remains efficient.

# %%
from foscat.Plot import plot_image_latlon

x_vals = ds.x.compute()
y_vals = ds.y.compute() 

# compute coordinate of the patch
xx, yy = np.meshgrid(x_vals, y_vals)
lon, lat = transformer.transform(xx, yy)

fig=plt.figure(figsize=(16,6))

ax=plt.subplot(1,2,1)
plot_image_latlon(fig,ax,ds["b02"].values-np.median(ds["b02"].values), lat, lon, mode="structured", shading="flat",vmin=-0.02,vmax=0.02,aspect="auto")
ax.set_title("b02")
ax=plt.subplot(1,2,2)
plot_image_latlon(fig,ax,ds["b04"].values-np.median(ds["b04"].values), lat, lon, mode="structured", shading="flat",vmin=-0.02,vmax=0.02,aspect="auto")
ax.set_title("b04")
# Out:
# Text(0.5, 1.0, 'b04')

# %% [markdown]
# ### Key cell — Patch-wise UTM → HEALPix projection with **xbatcher** and inverse interpolation per band
#
# This cell orchestrates a **patch-by-patch** conversion of Sentinel-2 image tiles (in UTM) to a **HEALPix** representation using **xbatcher** for tiling, and a **constrained inverse interpolation** to estimate the value of each HEALPix pixel so that the **HEALPix bilinear interpolation back to the UTM grid** reproduces the original image as closely as possible.
#
# **What it does, step by step**
#
# 1. **Batching (xbatcher)**
#    - The UTM image is partitioned into fixed-size patches (`pix_step × pix_step`, default `128×128`).
#    - This keeps memory usage low and enables scalable, parallel processing.
#
# 2. **Per-patch coordinate transform**
#    - For each patch, the code builds the (x, y) mesh in UTM, converts it to (lon, lat), and then to spherical angles `(theta, phi)`.
#
# 3. **Forward model: HEALPix → UTM via interpolation weights**
#    - Using `healpy.get_interp_weights(nside, theta, phi, nest=True)`, we retrieve, for each UTM pixel center, the **indices** of the HEALPix pixels and the **weights** that HEALPix would use to interpolate **from** HEALPix pixel values **to** that UTM location.
#    - Think of this as building a (very sparse) matrix **A** such that `u_utm ≈ A · v_hp`, where `v_hp` are unknown HEALPix pixel values on this patch footprint, and `u_utm` are the observed UTM pixel values.
#
# 4. **Inverse problem (per band)**
#    - For each band (B02 and B04), we **solve the normal equations** `AᵀA v_hp = Aᵀ u_utm` using a **conjugate-gradient** solver (`conjugate_gradient_normal_equation`).
#    - The solution **v_hp** is the set of HEALPix pixel values that, when interpolated with the same weights **A**, best reproduces the original UTM patch (in a least-squares sense).
#
# 5. **Quality and stability tweaks**
#    - The code filters cells that do not have enough contributing samples and renormalizes weights to avoid NaNs.
#    - This stabilizes the local inversion, especially along patch borders or near sparse sampling.
#
# 6. **Outputs per patch**
#    - `(vals_1, vals_2, cell_ids)`: the reconstructed HEALPix values for B02 and B04 and the corresponding HEALPix cell IDs (NESTED order) touched by the patch.
#
# **Why this is effective**
#
# - The process is **explicitly local and batched** (thanks to xbatcher), so it scales to very large scenes while keeping memory bounded.
# - By **matching the forward interpolation** used by HEALPix, the recovered HEALPix map is directly optimized for later **interpolated queries** (e.g., back to regular grids or to spectral/wavelet operators on the sphere).
# - Solving the **inverse interpolation** rather than simple bin-averaging gives a HEALPix field that is **closest (in least-squares sense)** to the original UTM radiometry when sampled through the same HEALPix interpolant.
#
# **A mental picture (proposed figure)**
#
# - Draw a small UTM patch as a square mesh of pixels.
# - Above it, draw a curved HEALPix mesh (cells on the sphere).
# - Arrows from **four neighboring HEALPix cells** converge to a **UTM pixel center** (these correspond to `get_interp_weights` indices/weights).
# - A caption: *“We form A from these arrows (weights). We then solve for v_hp so that A·v_hp ≈ u_utm. Later, evaluating A·v_hp gives back the UTM pixel values via the HEALPix interpolant.”*

# %%
from foscat.Plot import conjugate_gradient_normal_equation
import dask
import numpy as np
import xarray as xr
from xbatcher import BatchGenerator
import healpy as hp
from tqdm.auto import tqdm
import foscat.SphericalStencil as st

# Wavelet stencil on the sphere (used later in the pipeline)
f = st.SphericalStencil(2**19, 3)

def count_patches(xobj, input_dims, input_overlap):
    """
    Compute the total number of windows produced by xbatcher.
    Useful to drive tqdm progress bars.
    """
    stride = {k: input_dims[k] - input_overlap.get(k, 0) for k in input_dims}
    n = 1
    for dim, win in input_dims.items():
        step = stride[dim]
        size = xobj.sizes[dim]
        # classic sliding-window count: floor((size - win) / step) + 1
        n_dim = max(0, (size - win) // step + 1)
        n *= n_dim
    return n

def to_healpix_dask(
    level: int,
    ds: xr.Dataset,
    *,
    pix_step: int = 128,
    transformer=None,
    prefer_kdtree: bool = True,  # kept for API symmetry; weights path here uses healpy interpolation
):
    """
    Build a list of results (one per patch), each containing:
      (vals_1, vals_2, cell_ids)
    where vals_1/vals_2 are the estimated HEALPix pixel values for bands B02 and B04,
    and cell_ids are the NESTED-ordered HEALPix indices touched by this patch.

    Strategy
    --------
    For each UTM patch:
      1) Build (x, y) coordinate mesh and convert to (lon, lat) then (theta, phi).
      2) Use healpy.get_interp_weights to get interpolation indices/weights
         that map HEALPix values -> UTM pixel centers.
      3) Solve the inverse problem (normal equations) to recover HEALPix values
         that best reproduce the UTM patch when re-interpolated with those weights.
    """
    assert transformer is not None, "You must pass a CRS transformer with .transform(X, Y)."

    band = ds
    assert {"x", "y"} <= set(band.dims), "Dataset must have 'x' and 'y' dimensions."

    # Ensure patch size is integer
    pix_step = int(pix_step)
    input_dims = {"y": pix_step, "x": pix_step}
    input_overlap = {"y": 0, "x": 0}

    # Safety checks: xbatcher expects integers for window sizes/overlaps
    for k, v in input_dims.items():
        if not isinstance(v, (int, np.integer)):
            raise TypeError(f"input_dims[{k}] must be int, got {type(v)} -> {v}")
    for k, v in input_overlap.items():
        if not isinstance(v, (int, np.integer)):
            raise TypeError(f"input_overlap[{k}] must be int, got {type(v)} -> {v}")

    # Create the generator over (y, x) windows
    gen = BatchGenerator(
        band,               # xr.Dataset with variables 'b02' and 'b04' on (y, x)
        input_dims=input_dims,
        input_overlap=input_overlap,
    )

    total = count_patches(band, input_dims, input_overlap)

    def _process_patch(patch_ds, x_vals, y_vals):
        """
        For a single patch:
          - Build UTM coordinate grid
          - Convert to lon/lat -> (theta, phi)
          - Build HEALPix interpolation weights
          - Solve inverse interpolation for B02 and B04
        Returns:
          vals_1, vals_2, cell_ids
        """
        # Convert x/y coords to NumPy 1D arrays (handle dask if present)
        x_vals = x_vals.compute() if hasattr(x_vals, "compute") else np.asarray(x_vals)
        y_vals = y_vals.compute() if hasattr(y_vals, "compute") else np.asarray(y_vals)

        # UTM pixel-center coordinates for this patch
        xx, yy = np.meshgrid(x_vals, y_vals)

        # UTM -> lon/lat
        lon, lat = transformer.transform(xx, yy)

        # lon/lat -> spherical angles required by healpy:
        # theta = colatitude [0, pi], phi = longitude [0, 2*pi)
        theta = np.deg2rad(90.0 - lat).flatten()
        phi   = np.deg2rad(lon).flatten()

        # HEALPix resolution
        nside = 2**level
        
        # 1) Interp pattern from HEALPix -> UTM pixel centers.
        #    Shapes: I, W = (N_points, 4)
        I, W = hp.get_interp_weights(nside, theta, phi, nest=True)
        
        # 2) Repair & normalize weights row-wise (per UTM pixel)
        #    sumW shape: (N_points,)
        sumW = W.sum(axis=1)
        
        # pixels with no valid weights -> fallback to nearest HEALPix cell,
        # set weights to [1,0,0,0] (pure nearest-neighbor)
        bad = ~np.isfinite(sumW) | (sumW <= 0)
        if np.any(bad):
            fallback = hp.ang2pix(nside, theta[bad], phi[bad], nest=True)
            I[bad, :] = fallback[:, None]
            W[bad, :] = 0.0
            W[bad, 0] = 1.0
            sumW = W.sum(axis=1)  # recompute (now >= 1 everywhere)
        
        # normalize good rows so each row sums to 1
        good = sumW > 0
        W[good, :] /= sumW[good, None]
        
        # 3) Build unique cell list and inverse map
        #    Flatten (N,4) -> (4N,) to get a consistent 1D "indices" for the solver
        cell_ids, indices = np.unique(I.ravel(), return_inverse=True)
        # NOTE: 'indices' length is 4*N; the solver can ravel W internally (or do it here):
        # W_flat = W.ravel()  # if your solver expects 1D weights; otherwise keep 2D

        # Extract patch values (observations) for the two bands
        # Shape: (H, W) -> flatten to match the (N,) query points
        patch_1 = patch_ds["b02"].values
        patch_2 = patch_ds["b04"].values

        # Solve the normal equations for each band:
        #   minimize || A v_hp - u_utm ||_2
        # where A is defined implicitly by (I, W).
        vals_1 = conjugate_gradient_normal_equation(
            patch_1.flatten(),
            np.zeros([cell_ids.shape[0]]),
            W,
            indices,
            max_iter=100,
            verbose=False,
        )

        vals_2 = conjugate_gradient_normal_equation(
            patch_2.flatten(),
            np.zeros([cell_ids.shape[0]]),
            W,
            indices,
            max_iter=100,
            verbose=False,
        )

        return vals_1, vals_2, cell_ids

    # Iterate over patches and process
    data = []
    for patch in tqdm(gen, total=total, desc="Queuing patches"):
        x_slice = patch.coords["x"].data
        y_slice = patch.coords["y"].data
        # NOTE: As written, this calls _process_patch immediately (eager).
        # If you want lazy execution, wrap with dask.delayed(_process_patch)(...)
        l_data = _process_patch(patch, x_slice, y_slice)
        data.append(l_data)

    return data

# %%
# 1) Construire les tuiles lazy
data = to_healpix_dask(level=19, ds=ds, pix_step=256, transformer=transformer)
# Out:
# Queuing patches:   0%|          | 0/49 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # 1) Construire les tuiles lazy
# ----> 2 data = to_healpix_dask(level=19, ds=ds, pix_step=256, transformer=transformer)
#
# Cell In[13], line 169, in to_healpix_dask(level, ds, pix_step, transformer, prefer_kdtree)
#     166     y_slice = patch.coords["y"].data
#     167     # NOTE: As written, this calls _process_patch immediately (eager).
#     168     # If you want lazy execution, wrap with dask.delayed(_process_patch)(...)
# --> 169     l_data = _process_patch(patch, x_slice, y_slice)
#     170     data.append(l_data)
#     172 return data
#
# Cell In[13], line 142, in to_healpix_dask.<locals>._process_patch(patch_ds, x_vals, y_vals)
#     137 patch_2 = patch_ds["b04"].values
#     139 # Solve the normal equations for each band:
#     140 #   minimize || A v_hp - u_utm ||_2
#     141 # where A is defined implicitly by (I, W).
# --> 142 vals_1 = conjugate_gradient_normal_equation(
#     143     patch_1.flatten(),
#     144     np.zeros([cell_ids.shape[0]]),
#     145     W,
#     146     indices,
#     147     max_iter=100,
#     148     verbose=False,
#     149 )
#     151 vals_2 = conjugate_gradient_normal_equation(
#     152     patch_2.flatten(),
#     153     np.zeros([cell_ids.shape[0]]),
#    (...)    157     verbose=False,
#     158 )
#     160 return vals_1, vals_2, cell_ids
#
# File ~/miniconda3/envs/py311/lib/python3.11/site-packages/foscat/Plot.py:945, in conjugate_gradient_normal_equation(data, x0, www, all_idx, LPT, LP, max_iter, tol, verbose)
#     942 b = LPT(data, www, all_idx, hit)
#     944 # Compute initial residual r = b - A x, with A = Pᵗ P
# --> 945 Ax = LPT(LP(x, www, all_idx), www, all_idx, hit)
#     946 r = b - Ax
#     948 # Initialize direction
#
# File ~/miniconda3/envs/py311/lib/python3.11/site-packages/foscat/Plot.py:916, in conjugate_gradient_normal_equation.<locals>.default_P(x, W, indices)
#     908 def default_P(x, W, indices):
#     909     """
#     910     Forward operator: P(x) = projection of HEALPix map x onto the UTM grid.
#     911
#    (...)    914     - Interpolate from HEALPix cells to UTM pixels using weights W and indices.
#     915     """
# --> 916     return np.sum(x[indices] * W, 0)
#
# ValueError: operands could not be broadcast together with shapes (262144,) (4,65536)

# %%
from foscat.Plot import lgnomproject

plt.figure(figsize=(16,8))
for k in range(4):
    lgnomproject(data[k][2],data[k][0]-np.median(data[k][0]),2**19,hold=False,sub=(2,4,1+k),vmax=0.02,vmin=-0.02)
for k in range(4):
    lgnomproject(data[k][2],data[k][1]-np.median(data[k][1]),2**19,hold=False,sub=(2,4,5+k),vmax=0.02,vmin=-0.02)

# %%
KERNELSZ=5

x,y=np.meshgrid(np.arange(KERNELSZ)-KERNELSZ//2,np.arange(KERNELSZ)-KERNELSZ//2)

ww=np.zeros([1,2,KERNELSZ,KERNELSZ])
ww[0,0]=np.exp(-0.4*(x**2+y**2))*np.cos(x*np.pi)
ww[0,1]=np.exp(-0.4*(x**2+y**2))*np.sin(x*np.pi)

ww[0,0]-=np.mean(ww[0,0])
ww[0,1]-=np.mean(ww[0,1])
ww/=np.sqrt(np.sum(ww[0,0]**2+ww[0,1]**2))
plt.subplot(1,2,1)
plt.imshow(ww[0,0])
plt.subplot(1,2,2)
plt.imshow(ww[0,1])

# %%
import foscat.SphericalStencil as st

ww=f.to_tensor(ww.reshape(1,2,KERNELSZ*KERNELSZ))

def calc_wave_spectrum(data_b02,data_b04,cell_ids,ww,number_of_orientation=8,number_of_scale=6,nside=2**19):
    
    f=st.SphericalStencil(nside,KERNELSZ,gauge_type='phi',n_gauges=number_of_orientation)

    idx_wave=np.arange(number_of_orientation)*2

    l_data_a=f.to_tensor(data_b02[None,None,:])
    l_data_b=f.to_tensor(data_b04[None,None,:])
    l_cell_ids = cell_ids
    
    l_nside=nside
    
    wave_a=np.zeros([number_of_scale,number_of_orientation*2])
    wave_b=np.zeros([number_of_scale,number_of_orientation*2])
    wave_cross_amp=np.zeros([number_of_scale,number_of_orientation*2])
    wave_cross_dir=np.zeros([number_of_scale,number_of_orientation*2])

    for k in range(number_of_scale):
        a=f.to_numpy(f.Convol_torch(l_data_a,ww,cell_ids=l_cell_ids,nside=2**19))
        b=f.to_numpy(f.Convol_torch(l_data_b,ww,cell_ids=l_cell_ids,nside=2**19))

        wave_a[k,0:number_of_orientation]=np.median(np.sqrt(a[0,idx_wave]**2+a[0,idx_wave+1]**2),-1)
        wave_b[k,0:number_of_orientation]=np.median(np.sqrt(b[0,idx_wave]**2+b[0,idx_wave+1]**2),-1)

        wave_a[k,number_of_orientation:] = wave_a[k,0:number_of_orientation]
        wave_b[k,number_of_orientation:] = wave_b[k,0:number_of_orientation]
    
        val_cross_real=a[0,idx_wave]*b[0,idx_wave]+a[0,idx_wave+1]*b[0,idx_wave+1]
        val_cross_imag=a[0,idx_wave+1]*b[0,idx_wave]-a[0,idx_wave]*b[0,idx_wave+1]
        wave_cross_amp[k,:number_of_orientation]=np.median(val_cross_real,-1)
        wave_cross_dir[k,:number_of_orientation]=np.mean(np.arctan2(val_cross_imag,val_cross_real),-1)
    
        wave_cross_amp[k,number_of_orientation:] = wave_cross_amp[k,0:number_of_orientation]
        wave_cross_dir[k,number_of_orientation:] = -wave_cross_dir[k,0:number_of_orientation]
    
        l_data_a,new_cell_ids=f.Down(l_data_a,cell_ids=l_cell_ids,nside=l_nside)
        l_data_b,new_cell_ids=f.Down(l_data_b,cell_ids=l_cell_ids,nside=l_nside)
    
        l_nside//=2
        l_cell_ids=new_cell_ids

    return wave_a,wave_b,wave_cross_amp,wave_cross_dir

# %%
from foscat.Plot import plot_wave

for k in range(4):
    wave_a,wave_b,wave_cross_amp,wave_cross_dir=calc_wave_spectrum(data[k][0],data[k][1],data[k][2],ww)
    plt.figure(figsize=(16.0, 3.0))
    plt.subplot(1,5,1)
    plot_wave(wave_a,title='Wave spectrum b02')
    plt.subplot(1,5,2)
    plot_wave(wave_b,title='Wave spectrum b04')
    plt.subplot(1,5,3)
    plot_wave(wave_cross_amp,title='Wave spectrum b02xb04')
    plt.subplot(1,5,4)
    plot_wave(np.rad2deg(wave_cross_dir),unit='Phase',title='Wave Phase b02xb04',cmap="jet")

    lgnomproject(data[k][2],data[k][0]-np.median(data[k][0]),2**19,hold=False,sub=(1,5,5),vmax=0.02,vmin=-0.02,cbar=True,unit=r"$\Delta$ reflectance")

# %%
def to_wave_dask(
    level: int,
    ds: xr.Dataset,
    *,
    pix_step: int = 128,
    transformer=None,
    prefer_kdtree: bool = True,
):
    """
    Produit une liste de dask.delayed, chacun calculant (vals, cell_ids) pour une tuile.
    """
    assert transformer is not None, "You must pass a CRS transformer with .transform(X, Y)."

    band = ds
    assert {"x", "y"} <= set(band.dims)

    pix_step = int(pix_step)         # si pix_step venait d'une string
    overlap_y = 0
    overlap_x = 0

    input_dims = {"y": int(pix_step), "x": int(pix_step)}
    input_overlap = {"y": int(overlap_y), "x": int(overlap_x)}

    # sanity-check utile
    for k, v in input_dims.items():
        if not isinstance(v, (int, np.integer)):
            raise TypeError(f"input_dims[{k}] must be int, got {type(v)} -> {v}")
    for k, v in input_overlap.items():
        if not isinstance(v, (int, np.integer)):
            raise TypeError(f"input_overlap[{k}] must be int, got {type(v)} -> {v}")

    gen = BatchGenerator(
        band, 
        input_dims=input_dims,
        input_overlap=input_overlap,
    )

    total = count_patches(band, input_dims, input_overlap)
    
    def _process_patch(patch_ds, x_vals, y_vals):
        # s'assure d'avoir des numpy 1D
        x_vals = x_vals.compute() if hasattr(x_vals, "compute") else np.asarray(x_vals)
        y_vals = y_vals.compute() if hasattr(y_vals, "compute") else np.asarray(y_vals)

        # compute coordinate of the patch
        xx, yy = np.meshgrid(x_vals, y_vals)
        lon, lat = transformer.transform(xx, yy)

        theta = np.deg2rad(90.0 - lat).flatten()
        phi   = np.deg2rad(lon).flatten()

        nside = 2**level

         # Compute interpolation weights and indices for projecting from HEALPix to the UTM grid
        I, W = hp.get_interp_weights(nside,theta,phi, nest=True)

        # Identify the unique HEALPix cells that will contribute to u
        cell_ids, indices = np.unique(I, return_inverse=True)

        # remove cell_ids with not enough values
        valid_cell=np.bincount(indices.flatten(),W.flatten())
        W*=valid_cell[indices]>1.0
        W/=np.sum(W,0)[None,:]
        W[~np.isfinite(W)]=0.0
        valid_cell=np.bincount(indices.flatten(),W.flatten())
        i=0
        while valid_cell[i]!=0 and i<cell_ids.shape[0]-1:
            i+=1
        I[valid_cell[indices]==0]=cell_ids[i]
        
        cell_ids = hp.ang2pix(nside, theta, phi, nest=True)

        # Identify the unique HEALPix cells that will contribute to u
        cell_ids, indices = np.unique(I, return_inverse=True)
        
        patch_1 = patch_ds["b02"].values 
        patch_2 = patch_ds["b04"].values 
        
        # convert each band
        vals_1 = conjugate_gradient_normal_equation(patch_1.flatten(),
                                           np.zeros([cell_ids.shape[0]]),
                                           W,
                                           indices,
                                           max_iter=100,verbose=False)
        vals_2 = conjugate_gradient_normal_equation(patch_2.flatten(),
                                           np.zeros([cell_ids.shape[0]]),
                                           W,
                                           indices,
                                           max_iter=100,verbose=False)

        wave_a,wave_b,wave_cross_amp,wave_cross_dir=calc_wave_spectrum(vals_1,vals_2,cell_ids,ww)
        
        return wave_a,wave_b,wave_cross_amp,wave_cross_dir,np.median(lon),np.median(lat)

    results = []
    for patch in tqdm(gen, total=total, desc="Queuing patches"):
        x_slice = patch.coords["x"].data
        y_slice = patch.coords["y"].data
        all_result = _process_patch(patch, x_slice, y_slice)  # <- UN seul delayed qui contient (vals, ids)
        results.append(all_result)

    return results

# %%
# 1) Construire les tuiles lazy
result = to_wave_dask(level=19, ds=ds, pix_step=128, transformer=transformer)

# %%
# compute the coordinate of the results
center_lon=np.array([k[-2] for k in result])
center_lat=np.array([k[-1] for k in result])

# %%
from foscat.Plot import lonlat_edges_from_ref,spectrum_polar_to_cartesian

fig=plt.figure(figsize=(16,7))
plt.subplot(1,2,1)
for k in range(center_lon.shape[0]):
    img, kx, ky = spectrum_polar_to_cartesian(
                result[k][2],
                scales=2**np.arange(result[k][2].shape[0]),                 # tailles croissantes
                scale_kind="size",            # conversion automatique vers fréquence
                size_to_freq_factor=50.0,      # cycles / (unit of size) (Sentinel-2 10m résolution ~to 20m resoltuion for smaller scale; equiv. 50 cycles/km
                method="bicubic",
                n_pixels=64,
            )
    
    # Known reference: image center at ~Brest (just an example)
    ref_lat = center_lat[k]
    ref_lon = center_lon[k]
    dlon, dlat = 1.5E-4,1.5E-4   # 0.01° par pixel (≈ 1.1 km en lat)

    lon_e, lat_e = lonlat_edges_from_ref(img.shape, ref_lon, ref_lat, dlon, dlat, anchor="center")

    plt.pcolormesh(lon_e, lat_e, img, cmap='jet', shading="flat",vmax=1E-6)
    
plt.title("Wave spectrum from each patch")
plt.xlim(lon.min()-64*dlon,lon.max()+64*dlon)
plt.ylim(lat.min()-64*dlat,lat.max()+64*dlat)

x_vals = ds.x.compute()
y_vals = ds.y.compute() 
# compute coordinate of the patch
xx, yy = np.meshgrid(x_vals, y_vals)
lon, lat = transformer.transform(xx, yy)
ax=plt.subplot(1,2,2)
plot_image_latlon(fig,ax,ds["b02"].values-np.median(ds["b02"].values), lat, lon, mode="structured", shading="flat",vmin=-0.02,vmax=0.02,aspect="auto")
ax.set_title("b02")
